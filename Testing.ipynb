# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib as plt

# %%
#Testing
#Please add your names to confirm that you can change the notebook
#1. Michael
#2. <YOUR_NAME>

# %%
#Reading in dataset
df = pd.read_csv("competitor_market_prices_gas.csv")
df
# Out:
#          date_valid_from date_valid_to  rank  consumption_range_kwh  \
# 0             2021-09-01    2021-09-01     1                  22500
# 1             2021-09-01    2021-09-01     6                  90000
# 2             2021-09-01    2021-09-01    44                  24000
# 3             2021-09-01    2021-09-01    37                 150000
# 4             2021-09-01    2021-09-01    46                  20000
# ...                  ...           ...   ...                    ...
# 29373262      2022-09-13    2022-09-27     5                   2500
# 29373263      2022-09-13    2022-09-27    10                  80000
# 29373264      2022-09-13    2022-09-27    11                  20000
# 29373265      2022-09-13    2022-09-27    11                  18000
# 29373266      2022-09-13    2022-09-27     6                   3800
#
#              tariff supplier  price_year_eur  post_code           city energy
# ...
