# %%
import numpy as np
import pandas as pd
import sklearn as sk
import matplotlib.pyplot as plt

# %%
#path to the data folder, edit if necesssary
path = "./data/"

#filenames
file_power = "competitor_market_prices_power.csv"
file_gas = "competitor_market_prices_gas.csv"
clean_power = "clean_competitor_market_prices_power.csv"
clean_gas = "clean_competitor_market_prices_gas.csv"


#Price Filenames
spot_gas = "eex_spot_gas.csv"
d_ahead_gas = "eex_gas_d.csv"
y_ahead_gas = "eex_gas_y.csv"

spot_power = "epex_spot_power.csv"
d_ahead_peak = "eex_power_peak_d.csv"
y_ahead_peak = "eex_power_peak_y.csv"
d_ahead_base = "eex_power_base_d.csv"
y_ahead_base = "eex_power_base_y.csv"

# %%
df_gas = pd.read_csv(path + clean_gas)
df_gas.drop(columns = ['Unnamed: 0'], inplace = True)
df_gas
# Out:
#          date_valid_from date_valid_to  rank  consumption_range_kwh  \
# 0             2021-09-01    2021-09-01     1                  22500
# 1             2021-09-01    2021-09-01     6                  90000
# 2             2021-09-01    2021-09-01    44                  24000
# 3             2021-09-01    2021-09-01    46                  20000
# 4             2021-09-01    2021-09-01    49                  80000
# ...                  ...           ...   ...                    ...
# 17982680      2022-09-13    2022-09-27     8                  25000
# 17982681      2022-09-13    2022-09-27     9                  25000
# 17982682      2022-09-13    2022-09-27     6                   2300
# 17982683      2022-09-13    2022-09-27    11                  20000
# 17982684      2022-09-13    2022-09-27     6                   3800
#
#               tariff  supplier  price_year_eur  post_code         city energy
# 0            Shuppet     Willy         1340.77      58636     Iserlohn    gas
# 1          Rillaboom   Piteraq         5218.84      42277    Wuppertal    gas
# 2             Spheal    Belaja         1743.21      38226   Salzgitter    gas
# 3          Staraptor   Tornado         1542.88       3046      Cottbus    gas
# 4          Combusken  Kachchab         5203.17      81737      München    gas
# ...              ...       ...             ...        ...          ...    ...
# 17982680  Perrserker   Pulenat        10231.91      72762   Reutlingen    gas
# 17982681   Aegislash     Sarma        11507.30      71638  Ludwigsburg    gas
# 17982682    Ampharos     Sarma         1188.85      60439    Frankfurt    gas
# 17982683    Ampharos     Sarma         9230.80      12627       Berlin    gas
# 17982684    Ampharos     Sarma         1984.10      24109     Melsdorf    gas
#
# [17982685 rows x 10 columns]

# %%
df_power = pd.read_csv(path + clean_power)
df_power.drop(columns = ['Unnamed: 0'], inplace = True)
df_power
# Out:
#          date_valid_from date_valid_to  rank  consumption_range_kwh  \
# 0             2022-02-19    2022-02-20    22                   2400
# 1             2022-02-19    2022-02-20    31                   3600
# 2             2022-02-19    2022-02-20    26                   5500
# 3             2022-02-19    2022-02-20    22                    250
# 4             2022-02-19    2022-02-20    13                    500
# ...                  ...           ...   ...                    ...
# 32634484      2022-02-04    2022-02-07    31                   4000
# 32634485      2022-02-09    2022-02-09    40                   7800
# 32634486      2022-02-09    2022-02-09     2                   5600
# 32634487      2022-02-19    2022-02-20    16                   1000
# 32634488      2022-02-19    2022-02-20    45                   3000
#
#              tariff  supplier  price_year_eur  post_code  \
# 0          Nidorina   Solanus         1061.77      41751
# 1           Grookey     Purga         1562.37      31137
# 2          Appletun      Helm         2203.24      78054
# 3            Wimpod    Wambra          234.19      14480
# 4            Patrat   Pulenat          362.13      41462
# ...             ...       ...             ...        ...
# 32634484     Raichu   Solanus         1927.19       8058
# 32634485   Rookidee  Reshabar         5648.13      33332
# 32634486    Herdier     Joran         2278.78       8058
# 32634487  Gothorita  Lule älv          486.76      58452
# 32634488    Linoone    Caurus         1457.99      69126
#
#                             city energy
# 0                        Viersen  power
# 1                     Hildesheim  power
# 2         Villingen-Schwenningen  power
# 3                        Potsdam  power
# 4                          Neuss  power
# ...                          ...    ...
# 32634484                 Zwickau  power
# 32634485               Gütersloh  power
# 32634486                 Zwickau  power
# 32634487                  Witten  power
# 32634488              Heidelberg  power
#
# [32634489 rows x 10 columns]

# %%
#Joining Price Data
df_spot_power = pd.read_csv(path + spot_power, usecols = [0,1])
df_y_ahead_peak = pd.read_csv(path + y_ahead_peak, usecols = [0,1,2,3])
df_y_ahead_base = pd.read_csv(path + y_ahead_base, usecols = [0,1,2,3])
df_d_ahead_peak = pd.read_csv(path + d_ahead_peak, usecols = [0,1])
df_d_ahead_base = pd.read_csv(path + d_ahead_base, usecols = [0,1])

# %%
#Renaming columns
df_spot_power.rename(columns = {'d': 'spot'}, inplace = True)
df_y_ahead_peak.rename(columns = {'y01': 'y_ahead_peak',
                                 'y02': '2y_ahead_peak',
                                 'y03': '3y_ahead_peak'}, inplace = True)
df_y_ahead_base.rename(columns = {'y01': 'y_ahead_base',
                                 'y02': '2y_ahead_base',
                                 'y03': '3y_ahead_base'}, inplace = True)
df_d_ahead_peak.rename(columns = {'d00': 'd_ahead_peak'}, inplace = True)
df_d_ahead_base.rename(columns = {'d00': 'd_ahead_base'}, inplace = True)

df_y_ahead_base
# Out:
#             date  y_ahead_base  2y_ahead_base  3y_ahead_base
# 0     2022-10-13        424.00         268.01         185.24
# 1     2022-10-12        434.00         268.00         193.88
# 2     2022-10-11        435.64         270.00         194.92
# 3     2022-10-10        427.00         270.00         195.00
# 4     2022-10-09        427.00         270.00         195.00
# ...          ...           ...            ...            ...
# 1993  2017-04-29           NaN            NaN            NaN
# 1994  2017-04-28         29.63          27.50          27.54
# 1995  2017-04-27         29.41          27.32          27.46
# 1996  2017-04-26         29.35          27.22          27.31
# 1997  2017-04-25         29.07          27.13          27.28
#
# [1998 rows x 4 columns]

# %%
#Indexing Spot Price Data
df_spot_power.time = pd.to_datetime(df_spot_power.time)
df_spot_power['Dates'] = df_spot_power['time'].dt.date
df_spot_power.set_index('time', inplace = True)

# %%
#Generating Daily Peak and Base Prices
df_spot_power_peak = df_spot_power.between_time("08:00", "19:59")
df_spot_power_base = df_spot_power.between_time("20:00", "07:59")
df_spot_power_base = df_spot_power_base.groupby('Dates').mean()
df_spot_power_peak = df_spot_power_peak.groupby('Dates').mean()

#Renaming the columns and joining
df_spot_power_peak.rename(columns = {'spot': 'spot_peak'}, inplace = True)
df_spot_power_base.rename(columns = {'spot': 'spot_base'}, inplace = True)

#Joining the dataset
df_spot_power = pd.merge(df_spot_power_peak,df_spot_power_base, how='inner', left_index=True, right_index=True)
#df_spot_power['date'] = pd.to_datetime(df_spot_power.index)

# %%
#Joining all price data into master data
from datetime import datetime, timedelta

#Setting join date as index for joining to avoid lookahead bias
df_power.date_valid_from = pd.to_datetime(df_power.date_valid_from)
df_power.index = df_power.date_valid_from - timedelta(days = 1)


#Joining all price data
power_price_dfs = [df_y_ahead_peak, df_y_ahead_base, df_d_ahead_peak, df_d_ahead_base]

for df in power_price_dfs:
    df.set_index(pd.to_datetime(df.date), inplace = True)
    df.drop(columns = ['date'], inplace = True)
    df_spot_power = df_spot_power.join(df)
    
df_power_prices = df_spot_power
    
df_power_prices
# Out:
#              spot_peak   spot_base  y_ahead_peak  2y_ahead_peak  \
# Dates
# 2000-06-16   20.503333   13.749167           NaN            NaN
# 2000-06-17   15.180000   11.414167           NaN            NaN
# 2000-06-18   12.578333   10.225000           NaN            NaN
# 2000-06-19   21.919167   13.413333           NaN            NaN
# 2000-06-20   22.856667   13.870833           NaN            NaN
# ...                ...         ...           ...            ...
# 2022-10-10  186.518333  137.661667        581.64         353.67
# 2022-10-11  291.780833  227.966667        585.40         355.50
# 2022-10-12  299.796667  265.275000        590.00         355.46
# 2022-10-13  287.572500  227.339167        584.15         353.50
# 2022-10-14  283.841667  237.450000           NaN            NaN
#
#             3y_ahead_peak  y_ahead_base  2y_ahead_base  3y_ahead_base  \
# Dates
# 2000-06-16            NaN           NaN            NaN            NaN
# 2000-06-17            NaN           NaN            NaN            NaN
# 2000-06-18            NaN           NaN            NaN            NaN
# 2000-06-19            NaN           NaN            NaN            NaN
# 2000-06-20            NaN           NaN            NaN            NaN
# ...                   ...           ...            ...            ...
# 2022-10-10         254.50        427.00         270.00         195.00
# 2022-10-11         253.50        435.64         270.00         194.92
# 2022-10-12         253.61        434.00         268.00         193.88
# 2022-10-13         248.16        424.00         268.01         185.24
# 2022-10-14            NaN           NaN            NaN            NaN
#
#             d_ahead_peak  d_ahead_base
# Dates
# 2000-06-16           NaN           NaN
# 2000-06-17           NaN           NaN
# 2000-06-18           NaN           NaN
# 2000-06-19           NaN           NaN
# 2000-06-20           NaN           NaN
# ...                  ...           ...
# 2022-10-10        186.52        162.09
# 2022-10-11        291.78        259.87
# 2022-10-12        299.80        282.54
# 2022-10-13        287.57        257.46
# 2022-10-14           NaN           NaN
#
# [8156 rows x 10 columns]

# %%
#Joining all prices with df_power
df_power = df_power.join(df_power_prices)

# %%
df_power
# Out:
#            date_valid_from date_valid_to  rank  consumption_range_kwh  \
# 2021-05-24      2021-05-25    2021-09-21     3                    500
# 2021-05-24      2021-05-25    2021-09-22     2                    250
# 2021-05-24      2021-05-25    2021-09-22     2                    250
# 2021-05-24      2021-05-25    2021-09-22     3                    250
# 2021-05-24      2021-05-25    2021-09-21     3                    500
# ...                    ...           ...   ...                    ...
# 2022-10-14      2022-10-15    9999-12-31     8                   9000
# 2022-10-14      2022-10-15    9999-12-31    10                   4000
# 2022-10-14      2022-10-15    9999-12-31    19                   2000
# 2022-10-14      2022-10-15    9999-12-31    14                   5600
# 2022-10-14      2022-10-15    9999-12-31     3                   1200
#
#                tariff    supplier  price_year_eur  post_code  \
# 2021-05-24     Meltan     Criador          257.85      51469
# 2021-05-24     Meltan     Criador          183.92      51469
# 2021-05-24     Meltan     Criador          183.92      51381
# 2021-05-24     Meltan     Criador          185.12      51103
# 2021-05-24     Meltan     Criador          260.25      51103
# ...               ...         ...             ...        ...
# 2022-10-14  Gothorita    Lule älv         6568.43      58636
# 2022-10-14   Tsareena    Bergwind         2869.89      37085
# 2022-10-14   Lurantis       Purga         1686.23      46049
# 2022-10-14    Banette       Werra         4418.69      56070
# 2022-10-14    Dartrix  Canterbury          920.60      59071
#
#                          city energy   spot_peak  spot_base  y_ahead_peak  \
# 2021-05-24  Bergisch Gladbach  power   26.460833      36.83          74.6
# 2021-05-24  Bergisch Gladbach  power   26.460833      36.83          74.6
# 2021-05-24         Leverkusen  power   26.460833      36.83          74.6
# 2021-05-24               Köln  power   26.460833      36.83          74.6
# 2021-05-24               Köln  power   26.460833      36.83          74.6
# ...                       ...    ...         ...        ...           ...
# 2022-10-14           Iserlohn  power  283.841667     237.45           NaN
# 2022-10-14          Göttingen  power  283.841667     237.45           NaN
# 2022-10-14         Oberhausen  power  283.841667     237.45           NaN
# 2022-10-14            Koblenz  power  283.841667     237.45           NaN
# 2022-10-14               Hamm  power  283.841667     237.45           NaN
#
#             2y_ahead_peak  3y_ahead_peak  y_ahead_base  2y_ahead_base  \
# 2021-05-24          72.05          70.45          64.2          61.08
# 2021-05-24          72.05          70.45          64.2          61.08
# 2021-05-24          72.05          70.45          64.2          61.08
# 2021-05-24          72.05          70.45          64.2          61.08
# 2021-05-24          72.05          70.45          64.2          61.08
# ...                   ...            ...           ...            ...
# 2022-10-14            NaN            NaN           NaN            NaN
# 2022-10-14            NaN            NaN           NaN            NaN
# 2022-10-14            NaN            NaN           NaN            NaN
# 2022-10-14            NaN            NaN           NaN            NaN
# 2022-10-14            NaN            NaN           NaN            NaN
#
#             3y_ahead_base  d_ahead_peak  d_ahead_base
# 2021-05-24          59.28         26.46         31.65
# 2021-05-24          59.28         26.46         31.65
# 2021-05-24          59.28         26.46         31.65
# 2021-05-24          59.28         26.46         31.65
# 2021-05-24          59.28         26.46         31.65
# ...                   ...           ...           ...
# 2022-10-14            NaN           NaN           NaN
# 2022-10-14            NaN           NaN           NaN
# 2022-10-14            NaN           NaN           NaN
# 2022-10-14            NaN           NaN           NaN
# 2022-10-14            NaN           NaN           NaN
#
# [32634489 rows x 20 columns]

# %%
#Getting gas price data
df_spot_gas = pd.read_csv(path + spot_gas, usecols = [0,1])
df_y_ahead_gas = pd.read_csv(path + y_ahead_gas, usecols = [0,1,2,3])
df_d_ahead_gas = pd.read_csv(path + d_ahead_base, usecols = [0,1])

# %%
#Renaming columns
df_spot_gas.rename(columns = {'d': 'spot'}, inplace = True)
df_y_ahead_gas.rename(columns = {'y01': 'y_ahead_gas',
                                'y02': '2y_ahead_gas',
                                'y03': '3y_ahead_gas'}, inplace = True)
df_d_ahead_gas.rename(columns = {'d00': 'd_ahead_gas'}, inplace = True)

# %%
df_spot_gas
# Out:
#             date     spot
# 0     2022-10-14   98.389
# 1     2022-10-13  105.416
# 2     2022-10-12  106.853
# 3     2022-10-11  105.449
# 4     2022-10-10  119.323
# ...          ...      ...
# 4150  2011-06-04   22.960
# 4151  2011-06-03   22.990
# 4152  2011-06-02   23.170
# 4153  2011-06-01   22.790
# 4154  2011-05-31   23.180
#
# [4155 rows x 2 columns]

# %%
#Joining all gas price data into competitor dataset
from datetime import datetime, timedelta

#Setting join date as index for joining to avoid lookahead bias
df_gas.date_valid_from = pd.to_datetime(df_gas.date_valid_from)
df_gas.index = df_gas.date_valid_from - timedelta(days = 1)
df_gas
# Out:
#                 date_valid_from date_valid_to  rank  consumption_range_kwh  \
# date_valid_from
# 2021-08-31           2021-09-01    2021-09-01     1                  22500
# 2021-08-31           2021-09-01    2021-09-01     6                  90000
# 2021-08-31           2021-09-01    2021-09-01    44                  24000
# 2021-08-31           2021-09-01    2021-09-01    46                  20000
# 2021-08-31           2021-09-01    2021-09-01    49                  80000
# ...                         ...           ...   ...                    ...
# 2022-09-12           2022-09-13    2022-09-27     8                  25000
# 2022-09-12           2022-09-13    2022-09-27     9                  25000
# 2022-09-12           2022-09-13    2022-09-27     6                   2300
# 2022-09-12           2022-09-13    2022-09-27    11                  20000
# 2022-09-12           2022-09-13    2022-09-27     6                   3800
#
#                      tariff  supplier  price_year_eur  post_code         city  \
# date_valid_from
# 2021-08-31          Shuppet     Willy         1340.77      58636     Iserlohn
# 2021-08-31        Rillaboom   Piteraq         5218.84      42277    Wuppertal
# 2021-08-31           Spheal    Belaja         1743.21      38226   Salzgitter
# 2021-08-31        Staraptor   Tornado         1542.88       3046      Cottbus
# 2021-08-31        Combusken  Kachchab         5203.17      81737      München
# ...                     ...       ...             ...        ...          ...
# 2022-09-12       Perrserker   Pulenat        10231.91      72762   Reutlingen
# 2022-09-12        Aegislash     Sarma        11507.30      71638  Ludwigsburg
# 2022-09-12         Ampharos     Sarma         1188.85      60439    Frankfurt
# 2022-09-12         Ampharos     Sarma         9230.80      12627       Berlin
# 2022-09-12         Ampharos     Sarma         1984.10      24109     Melsdorf
#
#                 energy
# date_valid_from
# 2021-08-31         gas
# 2021-08-31         gas
# 2021-08-31         gas
# 2021-08-31         gas
# 2021-08-31         gas
# ...                ...
# 2022-09-12         gas
# 2022-09-12         gas
# 2022-09-12         gas
# 2022-09-12         gas
# 2022-09-12         gas
#
# [17982685 rows x 10 columns]

# %%
#Joining all price data
df_spot_gas.set_index('date', inplace = True)
df_y_ahead_gas.set_index('date', inplace = True)
df_d_ahead_gas.set_index('date', inplace = True)

#Joining all price data
gas_price_dfs = [df_y_ahead_gas, df_d_ahead_gas]

df_gas_prices = df_spot_gas

for df in gas_price_dfs:
    df_gas_prices = df_gas_prices.join(df)
    
df_gas_prices.index = pd.to_datetime(df_gas_prices.index)

# %%
df_gas = df_gas.join(df_gas_prices)
df_gas
# Out:
#            date_valid_from date_valid_to  rank  consumption_range_kwh  \
# 2021-05-20      2021-05-21    2021-09-01     1                   1000
# 2021-05-20      2021-05-21    2021-09-01     1                   1000
# 2021-05-20      2021-05-21    2021-09-01     1                   2500
# 2021-05-20      2021-05-21    2021-09-01     1                   5000
# 2021-05-20      2021-05-21    2021-09-01     1                   2300
# ...                    ...           ...   ...                    ...
# 2022-10-14      2022-10-15    9999-12-31     6                   2500
# 2022-10-14      2022-10-15    9999-12-31     4                   5000
# 2022-10-14      2022-10-15    9999-12-31     9                  22500
# 2022-10-14      2022-10-15    9999-12-31    10                  35000
# 2022-10-14      2022-10-15    9999-12-31    10                  40000
#
#                 tariff supplier  price_year_eur  post_code          city  \
# 2021-05-20    Sawsbuck  Levante          134.10      18109       Rostock
# 2021-05-20    Sawsbuck  Levante          128.40      89075           Ulm
# 2021-05-20    Sawsbuck  Levante          227.25      67063  Ludwigshafen
# 2021-05-20    Sawsbuck  Levante          368.50      51103          Köln
# 2021-05-20    Sawsbuck  Levante          214.83      67063  Ludwigshafen
# ...                ...      ...             ...        ...           ...
# 2022-10-14    Ampharos    Sarma          838.40      71638   Ludwigsburg
# 2022-10-14      Metang    Euros         1326.77      55118         Mainz
# 2022-10-14  Perrserker  Pulenat         6819.47      75181     Pforzheim
# 2022-10-14  Carracosta    Belat        10616.40      47137      Duisburg
# 2022-10-14  Carracosta    Belat        11867.33      71638   Ludwigsburg
#
#            energy    spot  y_ahead_gas  2y_ahead_gas  3y_ahead_gas  \
# 2021-05-20    gas  23.128          NaN           NaN           NaN
# 2021-05-20    gas  23.128          NaN           NaN           NaN
# 2021-05-20    gas  23.128          NaN           NaN           NaN
# 2021-05-20    gas  23.128          NaN           NaN           NaN
# 2021-05-20    gas  23.128          NaN           NaN           NaN
# ...           ...     ...          ...           ...           ...
# 2022-10-14    gas  98.389          NaN           NaN           NaN
# 2022-10-14    gas  98.389          NaN           NaN           NaN
# 2022-10-14    gas  98.389          NaN           NaN           NaN
# 2022-10-14    gas  98.389          NaN           NaN           NaN
# 2022-10-14    gas  98.389          NaN           NaN           NaN
#
#             d_ahead_gas
# 2021-05-20        69.99
# 2021-05-20        69.99
# 2021-05-20        69.99
# 2021-05-20        69.99
# 2021-05-20        69.99
# ...                 ...
# 2022-10-14          NaN
# 2022-10-14          NaN
# 2022-10-14          NaN
# 2022-10-14          NaN
# 2022-10-14          NaN
#
# [17982685 rows x 15 columns]

# %%
#Creating Supplier Strategy Index (Index 1 - 5 and None for suppliers showing up in the top 50 less than 1000 times)
gas_suppliers = df_gas[['supplier', 'rank']]
power_suppliers = df_power[['supplier', 'rank']]
gas_suppliers
# Out:
#            supplier  rank
# 2021-05-20  Levante     1
# 2021-05-20  Levante     1
# 2021-05-20  Levante     1
# 2021-05-20  Levante     1
# 2021-05-20  Levante     1
# ...             ...   ...
# 2022-10-14    Sarma     6
# 2022-10-14    Euros     4
# 2022-10-14  Pulenat     9
# 2022-10-14    Belat    10
# 2022-10-14    Belat    10
#
# [17982685 rows x 2 columns]

# %%
#Valid suppliers
gas_sup_counts = pd.DataFrame(gas_suppliers['supplier'].value_counts())
pow_sup_counts = pd.DataFrame(power_suppliers['supplier'].value_counts()) 
no_strat_gas_suppliers = gas_sup_counts.loc[gas_sup_counts.supplier < 1000]
no_strat_pow_suppliers = pow_sup_counts.loc[pow_sup_counts.supplier < 1000]

# %%
average_gas_ranks = pd.DataFrame(df_gas.loc[~df_gas['supplier'].isin(no_strat_gas_suppliers)].groupby('supplier')['rank'].mean())
average_power_ranks = pd.DataFrame(df_power.loc[~df_power['supplier'].isin(no_strat_pow_suppliers)].groupby('supplier')['rank'].mean())


#plt.hist(average_gas_ranks, range = (1, 50), bins = 20)
plt.hist(average_power_ranks, range = (1, 50), bins = 20)
# Out:
# (array([ 5.,  4.,  2.,  4.,  4., 11.,  8., 15., 19., 11., 10., 11., 10.,
#          8.,  9.,  2.,  3.,  2.,  1.,  1.]),
#  array([ 1.  ,  3.45,  5.9 ,  8.35, 10.8 , 13.25, 15.7 , 18.15, 20.6 ,
#         23.05, 25.5 , 27.95, 30.4 , 32.85, 35.3 , 37.75, 40.2 , 42.65,
#         45.1 , 47.55, 50.  ]),
#  <BarContainer object of 20 artists>)

# %%
bins = [1,2,3,4,5]
cutoffs = [0, 9, 19, 29, 39, 49]
average_gas_ranks['strat_index'] = pd.cut(average_gas_ranks['rank'], bins = cutoffs, labels = bins)
average_power_ranks['strat_index'] = pd.cut(average_power_ranks['rank'], bins = cutoffs, labels = bins)

# %%
#Adding Strategy Indices to Datasets
df_power = df_power.merge(average_power_ranks[['strat_index']], left_on = 'supplier', right_on = average_power_ranks.index)
df_gas = df_gas.merge(average_gas_ranks[['strat_index']], left_on = 'supplier', right_on = average_gas_ranks.index)

# %%
df_gas
# Out:
#          date_valid_from date_valid_to  rank  consumption_range_kwh    tariff  \
# 0             2021-05-21    2021-09-01     1                   1000  Sawsbuck
# 1             2021-05-21    2021-09-01     1                   1000  Sawsbuck
# 2             2021-05-21    2021-09-01     1                   2500  Sawsbuck
# 3             2021-05-21    2021-09-01     1                   5000  Sawsbuck
# 4             2021-05-21    2021-09-01     1                   2300  Sawsbuck
# ...                  ...           ...   ...                    ...       ...
# 17982680      2022-09-10    2022-09-15     1                   2000   Mudbray
# 17982681      2022-09-10    2022-09-15     1                  17000   Mudbray
# 17982682      2022-09-10    2022-09-15     1                  12000   Mudbray
# 17982683      2022-09-10    2022-09-15     1                   1000   Mudbray
# 17982684      2022-09-10    2022-09-15     1                  22500   Mudbray
#
#          supplier  price_year_eur  post_code          city energy     spot  \
# 0         Levante          134.10      18109       Rostock    gas   23.128
# 1         Levante          128.40      89075           Ulm    gas   23.128
# 2         Levante          227.25      67063  Ludwigshafen    gas   23.128
# 3         Levante          368.50      51103          Köln    gas   23.128
# 4         Levante          214.83      67063  Ludwigshafen    gas   23.128
# ...           ...             ...        ...           ...    ...      ...
# 17982680  Chanduy          519.32      85055    Ingolstadt    gas  198.332
# 17982681  Chanduy         3818.35      85055    Ingolstadt    gas  198.332
# 17982682  Chanduy         2753.90      85055    Ingolstadt    gas  198.332
# 17982683  Chanduy          289.29      85055    Ingolstadt    gas  198.332
# 17982684  Chanduy         4989.25      85055    Ingolstadt    gas  198.332
#
#           y_ahead_gas  2y_ahead_gas  3y_ahead_gas  d_ahead_gas strat_index
# 0                 NaN           NaN           NaN        69.99           3
# 1                 NaN           NaN           NaN        69.99           3
# 2                 NaN           NaN           NaN        69.99           3
# 3                 NaN           NaN           NaN        69.99           3
# 4                 NaN           NaN           NaN        69.99           3
# ...               ...           ...           ...          ...         ...
# 17982680      194.575        128.82          89.6       345.70           1
# 17982681      194.575        128.82          89.6       345.70           1
# 17982682      194.575        128.82          89.6       345.70           1
# 17982683      194.575        128.82          89.6       345.70           1
# 17982684      194.575        128.82          89.6       345.70           1
#
# [17982685 rows x 16 columns]

# %%
df_power
# Out:
#          date_valid_from date_valid_to  rank  consumption_range_kwh   tariff  \
# 0             2021-05-25    2021-09-21     3                    500   Meltan
# 1             2021-05-25    2021-09-22     2                    250   Meltan
# 2             2021-05-25    2021-09-22     2                    250   Meltan
# 3             2021-05-25    2021-09-22     3                    250   Meltan
# 4             2021-05-25    2021-09-21     3                    500   Meltan
# ...                  ...           ...   ...                    ...      ...
# 32634484      2022-09-14    2022-09-16     1                   1200  Starmie
# 32634485      2022-09-14    2022-09-16     1                  20000  Starmie
# 32634486      2022-09-14    2022-09-16     1                    250  Starmie
# 32634487      2022-09-14    2022-09-16     1                   2500  Starmie
# 32634488      2022-09-14    2022-09-16     1                   2400  Starmie
#
#          supplier  price_year_eur  post_code               city energy  ...  \
# 0         Criador          257.85      51469  Bergisch Gladbach  power  ...
# 1         Criador          183.92      51469  Bergisch Gladbach  power  ...
# 2         Criador          183.92      51381         Leverkusen  power  ...
# 3         Criador          185.12      51103               Köln  power  ...
# 4         Criador          260.25      51103               Köln  power  ...
# ...           ...             ...        ...                ...    ...  ...
# 32634484  Chanduy          555.72      85055         Ingolstadt  power  ...
# 32634485  Chanduy         7799.36      85055         Ingolstadt  power  ...
# 32634486  Chanduy          189.68      85055         Ingolstadt  power  ...
# 32634487  Chanduy         1056.61      85055         Ingolstadt  power  ...
# 32634488  Chanduy         1018.08      85055         Ingolstadt  power  ...
#
#           spot_base  y_ahead_peak  2y_ahead_peak  3y_ahead_peak  y_ahead_base  \
# 0           36.8300         74.60          72.05          70.45         64.20
# 1           36.8300         74.60          72.05          70.45         64.20
# 2           36.8300         74.60          72.05          70.45         64.20
# 3           36.8300         74.60          72.05          70.45         64.20
# 4           36.8300         74.60          72.05          70.45         64.20
# ...             ...           ...            ...            ...           ...
# 32634484   373.1425        669.67         341.30         269.28        476.75
# 32634485   373.1425        669.67         341.30         269.28        476.75
# 32634486   373.1425        669.67         341.30         269.28        476.75
# 32634487   373.1425        669.67         341.30         269.28        476.75
# 32634488   373.1425        669.67         341.30         269.28        476.75
#
#           2y_ahead_base  3y_ahead_base  d_ahead_peak  d_ahead_base  \
# 0                 61.08          59.28         26.46         31.65
# 1                 61.08          59.28         26.46         31.65
# 2                 61.08          59.28         26.46         31.65
# 3                 61.08          59.28         26.46         31.65
# 4                 61.08          59.28         26.46         31.65
# ...                 ...            ...           ...           ...
# 32634484         236.30         183.00        411.60        392.37
# 32634485         236.30         183.00        411.60        392.37
# 32634486         236.30         183.00        411.60        392.37
# 32634487         236.30         183.00        411.60        392.37
# 32634488         236.30         183.00        411.60        392.37
#
#           strat_index
# 0                   2
# 1                   2
# 2                   2
# 3                   2
# 4                   2
# ...               ...
# 32634484            1
# 32634485            1
# 32634486            1
# 32634487            1
# 32634488            1
#
# [32634489 rows x 21 columns]

# %%
df_gas.to_csv(path + "master_" + file_gas)
df_power.to_csv(path + "master_" + file_gas)
