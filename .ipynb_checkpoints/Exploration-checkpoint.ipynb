# %% [markdown]
# # Visualizing Price Movement

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#path to the data folder, edit if necesssary
path = "./data/"

#filenames
file_power = "competitor_market_prices_power.csv"
file_gas = "competitor_market_prices_gas.csv"
clean_power = "clean_competitor_market_prices_power.csv"
clean_gas = "clean_competitor_market_prices_gas.csv"


#Price Filenames
power_prices = 'power_prices'
gas_prices = 'gas_prices'

# %%
#Reading in gas and power prices
df_power_prices = pd.read_csv(path + power_prices, index_col = 'Dates')
df_gas_prices = pd.read_csv(path + gas_prices, index_col = 'date')

df_power_prices = df_power_prices.loc[df_power_prices.index > "2021-05-24"]
df_gas_prices = df_gas_prices.loc[df_gas_prices.index > "2021-05-24"]

df_power_prices
# Out:
#              spot_peak   spot_base  y_ahead_peak  2y_ahead_peak  \
# Dates
# 2021-05-25   59.137500   59.780417         75.47          72.68
# 2021-05-26   66.536667   65.605833         77.00          73.15
# 2021-05-27   73.450833   71.767500         75.05          71.82
# 2021-05-28   73.577500   73.602083         74.30          71.08
# 2021-05-29   45.800833   56.487917         74.05          70.75
# ...                ...         ...           ...            ...
# 2022-10-10  186.518333  162.090000        581.64         353.67
# 2022-10-11  291.780833  259.873750        585.40         355.50
# 2022-10-12  299.796667  282.535833        590.00         355.46
# 2022-10-13  287.572500  257.455833        584.15         353.50
# 2022-10-14  283.841667  260.645833           NaN            NaN
#
#             3y_ahead_peak  y_ahead_base  2y_ahead_base  3y_ahead_base  \
# Dates
# 2021-05-25          70.68         64.97          61.66          59.90
# 2021-05-26          71.00         66.21          62.18          60.22
# 2021-05-27          70.44         64.24          60.53          58.83
# 2021-05-28          69.50         63.96          60.08          58.13
# 2021-05-29          69.47         63.52          59.84          57.85
# ...                   ...           ...            ...            ...
# 2022-10-10         254.50        427.00         270.00         195.00
# 2022-10-11         253.50        435.64         270.00         194.92
# 2022-10-12         253.61        434.00         268.00         193.88
# 2022-10-13         248.16        424.00         268.01         185.24
# 2022-10-14            NaN           NaN            NaN            NaN
#
#             d_ahead_peak  d_ahead_base  m_ahead_base  6m_ahead_base  \
# Dates
# 2021-05-25         59.14         59.78         64.77          76.86
# 2021-05-26         66.54         65.61         66.91          79.14
# 2021-05-27         73.45         71.77         65.82          76.58
# 2021-05-28         73.58         73.60         64.96          75.89
# 2021-05-29         45.80         56.49         53.35          68.40
# ...                  ...           ...           ...            ...
# 2022-10-10        186.52        162.09        344.89         389.71
# 2022-10-11        291.78        259.87        345.31         398.27
# 2022-10-12        299.80        282.54        341.97         389.53
# 2022-10-13        287.57        257.46        336.63         383.04
# 2022-10-14           NaN           NaN           NaN            NaN
#
#             m_ahead_peak  6m_ahead_peak
# Dates
# 2021-05-25         71.40          91.49
# 2021-05-26         73.63          93.96
# 2021-05-27         72.16          90.86
# 2021-05-28         70.65          90.33
# 2021-05-29         70.43          90.33
# ...                  ...            ...
# 2022-10-10        470.80         492.09
# 2022-10-11        469.67         492.92
# 2022-10-12        454.50         485.41
# 2022-10-13        449.29         473.85
# 2022-10-14           NaN            NaN
#
# [508 rows x 14 columns]

# %%
#Visualizing missing price data with heatmap
sns.heatmap(df_gas_prices.isnull())
# Out:
# <AxesSubplot:ylabel='date'>

# %%
#Dealing with missing price data
#df_power_prices.isna().sum()
df_gas_prices.isna().sum()
# Out:
# spot             0
# y_ahead_gas     36
# 2y_ahead_gas    36
# 3y_ahead_gas    36
# d_ahead_gas     32
# m_ahead_gas     36
# 4m_ahead_gas    36
# dtype: int64

# %%
df_gas_prices.index = pd.to_datetime(df_gas_prices.index)
df_power_prices.index = pd.to_datetime(df_power_prices.index)

# %%
#Visualizing spot price movements
spot_prices = df_power_prices[['spot_peak', 'spot_base']]
y_ahead_prices = df_power_prices[['y_ahead_peak', '2y_ahead_peak', '3y_ahead_peak', 'y_ahead_base', '2y_ahead_base', '3y_ahead_base']]

fig = plt.figure(figsize = (20,10)) 
plt.title("Power Spot Price movements", fontsize='16')
plt.plot(spot_prices.spot_base, label = 'spot_base')
plt.plot(spot_prices.spot_peak, label = 'spot_peak')
plt.legend()
plt.show()

# %%
# Out:
# ['spot_peak', 'spot_base']
